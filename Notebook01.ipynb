# %%
a=3
if a<3:
    print(a)
elif a>3:
    print("not")
elif a==3:
    print("bob")
# Out:
# bob

# %% [markdown]
# # This is a text example in a jupyter notebook
# * item 1
# * item 2 **bold** text in bold **bold**
#     *  item 3

# %%
bool(a)
a=3
a
# Out:
# 3

# %%
a=3
b=4
bool(a==b)
# Out:
# False

# %%
import numpy as np

t=np.deg2rad(180)
print(t)
u=np.rad2deg(2*np.pi)
print(u)
a=[1,2,3]
print(a[0], a[1]) 
b=["eland",2, 8*5, np.pi]
print(b)
print(b[1])
# Out:
# 3.141592653589793
# 360.0
# 1 2
# ['eland', 2, 40, 3.141592653589793]
# 2

# %%
def sum(a, b, sign):
    if sign == '+':
        return a + b
    elif sign == '-':
        return a - b
    else:
        return ("invalid sign")
    
d=sum(10,3, '-')
d
# Out:
# 7

# %%
import numpy as np
t=np.cos(13)
t
# Out:
# np.float64(0.9074467814501962)
